# %%
import trecs
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter1d
from collections import defaultdict
from chaney_utils import (
    load_sim_results,
    merge_results,
    graph_relative_to_ideal
)
import warnings
warnings.simplefilter("ignore")

# %%
DEBUG = True # don't save figures

# %% [markdown]
# # Experimental simulations run on cluster

# %%
# graphing
plt.style.use('seaborn-whitegrid')
plt.rcParams.update({'font.size': 14})

# readable legend keys
id_to_readable = {
    "ideal": "ideal", 
    "content_chaney": "content filtering",
    "mf" : "matrix factorization",
    "sf": "social filtering",
    "popularity": "popularity", 
    "random": "random"
}

# %% [markdown]
# ## Repeated training, change in jaccard index (similar users paired)

# %%
# replace with the experimental output directory in your experiment!
rep_results = merge_results(["results/repeated"])

# %%
model_keys = ["ideal", "content_chaney", "mf", "sf", "popularity", "random"]
graph_relative_to_ideal(rep_results, "sim_users", model_keys, id_to_readable, absolute_measure=False, mult_sd=1.0)
plt.ylabel("Change in Jaccard Index in Similar Users")
plt.xlabel("Timestep")
plt.legend(facecolor='white', framealpha=1, loc='upper right', bbox_to_anchor=(1.7, 1.0))
plt.ylim(-0.15, 0.3)
plt.xlim(0, 100)
if not DEBUG:
    plt.savefig("figures/repeated_training_sim_pair.pdf", bbox_inches = "tight")

# %%
model_keys = ["ideal", "content_chaney", "mf", "sf", "popularity", "random"]
graph_relative_to_ideal(rep_results, "random_users", model_keys, id_to_readable, absolute_measure=True, mult_sd=1.0)
plt.ylabel("Change in Jaccard Index in Random Users")
plt.xlabel("Timestep")
plt.legend(facecolor='white', framealpha=1, loc='upper right', bbox_to_anchor=(1.7, 1.0))
plt.ylim(-0.1, 0.3)
plt.xlim(0, 100)
if not DEBUG:
    plt.savefig("figures/repeated_training_sim_pair.pdf", bbox_inches = "tight")

# %%
model_keys = ["ideal", "content_chaney", "mf", "sf", "popularity", "random"]
graph_relative_to_ideal(rep_results, "mean_item_dist", model_keys, id_to_readable, absolute_measure=False, mult_sd=1.0)
plt.ylabel("Mean Interaction Distance")
plt.xlabel("Timestep")
plt.legend(facecolor='white', framealpha=1, loc='upper right', bbox_to_anchor=(1.7, 1.0))
plt.ylim(-0.5, 1)
plt.xlim(0, 100)
if not DEBUG:
    plt.savefig("figures/repeated_training_sim_pair.pdf", bbox_inches = "tight")

# %%
model_keys = ["ideal", "content_chaney", "mf", "sf", "popularity", "random"]
graph_relative_to_ideal(rep_results, "sim_user_dist", model_keys, id_to_readable, absolute_measure=False, mult_sd=1.0)
plt.ylabel("Mean Interaction Distance Similar Users")
plt.xlabel("Timestep")
plt.legend(facecolor='white', framealpha=1, loc='upper right', bbox_to_anchor=(1.7, 1.0))
plt.ylim(-0.5, 0.1)
plt.xlim(0, 100)
if not DEBUG:
    plt.savefig("figures/repeated_training_sim_pair.pdf", bbox_inches = "tight")

# %% [markdown]
# ## Single training, change in jaccard index (similar users paired)

# %%
# replace with the experimental output directory in your experiment!
single_results = merge_results(["results/single"])

# %%
model_keys = ["ideal", "content_chaney", "mf", "sf", "popularity", "random"]
graph_relative_to_ideal(single_results, "sim_users", model_keys, id_to_readable, absolute_measure=False, mult_sd=1.0)
plt.ylabel("Change in Jaccard Index in Similar Users")
plt.xlabel("Timestep")
plt.legend(facecolor='white', framealpha=1, loc='upper right', bbox_to_anchor=(1.6, 1.0))
plt.ylim(-0.1, 0.15)
plt.xlim(0, 100)
if not DEBUG:
    plt.savefig("figures/single_training_sim_pair.pdf", bbox_inches = "tight")

# %%
model_keys = ["ideal", "content_chaney", "mf", "sf", "popularity", "random"]
graph_relative_to_ideal(single_results, "random_users", model_keys, id_to_readable, absolute_measure=True, mult_sd=1.0)
plt.ylabel("Change in Jaccard Index in Random Users")
plt.xlabel("Timestep")
plt.legend(facecolor='white', framealpha=1, loc='upper right', bbox_to_anchor=(1.6, 1.0))
plt.ylim(-0.1, 0.15)
plt.xlim(0, 100)
if not DEBUG:
    plt.savefig("figures/single_training_sim_pair.pdf", bbox_inches = "tight")

# %%
model_keys = ["ideal", "content_chaney", "mf", "sf", "popularity", "random"]
graph_relative_to_ideal(single_results, "mean_item_dist", model_keys, id_to_readable, absolute_measure=False, mult_sd=1.0)
plt.ylabel("Mean Interaction Distance")
plt.xlabel("Timestep")
plt.legend(facecolor='white', framealpha=1, loc='upper right', bbox_to_anchor=(1.7, 1.0))
plt.ylim(-0.5, 1)
plt.xlim(0, 100)
if not DEBUG:
    plt.savefig("figures/repeated_training_sim_pair.pdf", bbox_inches = "tight")

# %%
model_keys = ["ideal", "content_chaney", "mf", "sf", "popularity", "random"]
graph_relative_to_ideal(single_results, "sim_user_dist", model_keys, id_to_readable, absolute_measure=False, mult_sd=1.0)
plt.ylabel("Mean Interaction Distance Similar Users")
plt.xlabel("Timestep")
plt.legend(facecolor='white', framealpha=1, loc='upper right', bbox_to_anchor=(1.7, 1.0))
plt.ylim(-0.5, 0.1)
plt.xlim(0, 100)
if not DEBUG:
    plt.savefig("figures/repeated_training_sim_pair.pdf", bbox_inches = "tight")
